# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
fig = Figure()
canvas = FigureCanvas(fig)

import numpy as np
x = np.random.rand(1000)

ax = fig.add_subplot(111)
ax.hist(x, 100)
ax.set_title("Normalization")
fig.savefig('matplotlib_histogram.png')
fig.show
# Out:
# <bound method Figure.show of <Figure size 640x480 with 1 Axes>>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
plt.hist(x, 100)
plt.title('Normal Distribution')
plt.show()

# %%
import matplotlib as mpl
import pandas as pd
years = list(np.random.rand(5))
RecordsList = [123,234,345]
data = pd.DataFrame(years, ['Record1', 'Record2','Record3','Record4','Record5'])
# data = data.set_index(data[0], inplace=True)
data.plot(kind='line')
plt.title('Random Line Plot')
plt.xlabel('Record Names')
plt.ylabel('Record Numbers')
plt.show()
